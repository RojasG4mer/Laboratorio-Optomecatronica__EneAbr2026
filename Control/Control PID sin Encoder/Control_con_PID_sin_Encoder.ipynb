# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
P = pd.read_csv('PID sin encoder - P.csv')
PI = pd.read_csv('PID sin encoder - PI.csv')
PID = pd.read_csv('PID sin encoder - PID.csv')
columnasP = P.columns.tolist()
columnasPI = PI.columns.tolist()
columnasPID = PID.columns.tolist()
print(columnasP)
print(columnasPI)
print(columnasPID)
# Out:
# ['Time - Setpoint', 'Amplitude - Setpoint', 'Time - PV', 'Tiempo real', 'Amplitude - PV', 'Time - Error', 'Amplitude - Error', 'Unnamed: 7']
# ['Time - Setpoint', 'Amplitude - Setpoint', 'Time - PV', 'Tiempo real', 'Amplitude - PV', 'Time - Error', 'Amplitude - Error', 'Unnamed: 7']
# ['Time - Setpoint', 'Amplitude - Setpoint', 'Time - PV', 'Amplitude - PV', 'Time - Error', 'Amplitude - Error', 'Unnamed: 6']

# %%
PID_correccion = pd.read_csv('PID sin encoder - Ejercicio 4.csv')
columnasPID_correccion = PID_correccion.columns.tolist()
print(columnasPID_correccion)
# Out:
# ['Time - Setpoint', 'Amplitude - Setpoint', 'Time - PV', 'Amplitude - PV', 'Time - Error', 'Amplitude - Error', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8']

# %% [markdown]
# ## Grafica de P

# %%
plt.figure(figsize=(10, 6))
plt.plot(P[columnasP[3]], P[columnasP[4]], label='Posición', color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (V)')
plt.title('Control P sin Encoder')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Grafica para PI

# %%
plt.figure(figsize=(10, 6))
plt.plot(PI[columnasP[3]], PI[columnasP[4]], label='Posición', color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (V)')
plt.title('Control PI sin Encoder')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Grafica para PID

# %%
plt.figure(figsize=(10, 6))
plt.plot(PID[columnasPID[2]] * 0.2, PID[columnasPID[3]], label='Posición', color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (V)')
plt.title('Control PID sin Encoder')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Las 3 juntas

# %%
n = 60000 # a minutos desde milisegundos

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(P[columnasP[3]] / n, P[columnasP[4]], label='Posición', color='green')
axs[0].plot(P[columnasP[3]] / n, P[columnasP[1]], label='Setpoint', color='red')
axs[0].set_xlabel('Tiempo (min)')
axs[0].set_ylabel('Amplitud (V)')
axs[0].set_title('Control P sin Encoder')
axs[0].legend()
axs[0].grid()

axs[1].plot(PI[columnasP[3]] / n, PI[columnasP[4]], label='Posición', color='blue')
axs[1].plot(PI[columnasP[3]] / n, PI[columnasP[1]], label='Setpoint', color='red')
axs[1].set_xlabel('Tiempo (min)')
axs[1].set_ylabel('Amplitud (V)')
axs[1].set_title('Control PI sin Encoder')
axs[1].legend()
axs[1].grid()

axs[2].plot(PID[columnasPID[2]] / n, PID[columnasPID[3]], label='Posición', color='blue')
axs[2].plot(PID[columnasPID[2]] / n, PID[columnasPID[1]], label='Setpoint', color='red')
axs[2].set_xlabel('Tiempo (min)')
axs[2].set_ylabel('Amplitud (V)')
axs[2].set_title('Control PID sin Encoder')
axs[2].legend()
axs[2].grid()

plt.show()

# %% [markdown]
# ## Ejercicio 4

# %%
print(columnasPID_correccion)
# Out:
# ['Time - Setpoint', 'Amplitude - Setpoint', 'Time - PV', 'Amplitude - PV', 'Time - Error', 'Amplitude - Error', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8']

# %%
figsize = (15, 5)
plt.plot(PID_correccion[columnasPID_correccion[2]] / n, PID_correccion[columnasPID_correccion[3]], label='PV', color='green' )
plt.plot(PID_correccion[columnasPID_correccion[2]] / n, PID_correccion[columnasPID_correccion[1]], label='Setpoint', color='red' )
plt.xlabel('Tiempo (min)')
plt.ylabel('Amplitud (V)')
plt.title('Control PID sin Encoder - Mejorar el amortiguamiento')
plt.legend()
plt.grid()
plt.show()
